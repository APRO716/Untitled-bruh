# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]     #ข้อมูลในแนแกน x
y = [5,15,15,20,10] #ข้อมูลในแกน y
plt.plot(x,y)       #วาดกราฟ
plt.show()

# %%
import matplotlib.pyplot as plt #1.1
x = [2,3,4,5,6,7,8,9,10]     #ข้อมูลในแนแกน x
y = [10,15,20,25,30,35,40,45,50] #ข้อมูลในแกน y
plt.plot(x,y)       #วาดกราฟ
plt.show()

# %%
import matplotlib.pyplot as plt
data = [5,20,10,15,10]
plt.plot(data)
plt.show()

# %%
import matplotlib.pyplot as plt #1.2
data = [50,10,30,15,40]
plt.plot(data)
plt.show()

# %%
import matplotlib.pyplot as plt
y = [5,20,10,15,10]     #ข้อมูลในแนแกน y
x = ['Mon','Tue','Wed','Thu','Fri'] #ข้อมูลในแกน x
plt.xlabel('Day')
plt.ylabel('Y')
plt.plot(x,y, color='red')
plt.show()

# %%
import matplotlib.pyplot as plt #1.3
y = [40,20,50,30,10]     #ข้อมูลในแนแกน y
x = ['Jan','Feb','Mar','Apr','May'] #ข้อมูลในแกน x
plt.xlabel('Month')
plt.ylabel('Y')
plt.plot(x,y, color='magenta')
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]     #ข้อมูลในแนแกน x
y = [5,15,15,20,10] #ข้อมูลในแกน y
plt.plot(x,y,ls='--')
plt.show()

# %%
import matplotlib.pyplot as plt #1.4
x = [1,2,3,4,5]     #ข้อมูลในแนแกน x
y = [5,15,15,20,10] #ข้อมูลในแกน y
plt.plot(x,y,ls='-.')
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]     #ข้อมูลในแนแกน x
y = [5,15,15,20,10] #ข้อมูลในแกน y
plt.plot(x,y,'go--')
plt.show()

# %%
import matplotlib.pyplot as plt #1.5
x = [1,2,3,4,5]     #ข้อมูลในแนแกน x
y = [5,15,15,20,10] #ข้อมูลในแกน y
plt.plot(x,y,'bs-.')
plt.show()

# %%
import matplotlib.pyplot as plt
y = [50,70,35,90,40]     #ข้อมูลในแนแกน y
x = ['Mon','Tue','Wed','Thu','Fri'] #ข้อมูลในแกน x
plt.bar(x,y)
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt #2.1
y = [20,50,40,90,70]     #ข้อมูลในแนแกน y
x = ['Aug','Sep','Oct','Nov','Dec'] #ข้อมูลในแกน x
plt.bar(x,y)
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
y = [50,70,35,90,40]     #ข้อมูลในแนแกน y
x = ['Mon','Tue','Wed','Thu','Fri'] #ข้อมูลในแกน x
plt.barh(x,y, color='green', hatch='\\')
plt.show()

# %%
import matplotlib.pyplot as plt
y = [50,70,35,90,40]     #ข้อมูลในแนแกน y
x = ['Mon','Tue','Wed','Thu','Fri'] #ข้อมูลในแกน x
plt.barh(x,y, color='lightseagreen', hatch='x')
plt.show()

# %%
import matplotlib.pyplot as plt #3.1
data = [40,25,20,5,10]
lb = ['Netflix','Viu','Disney Hotstar','We TV','iQIYI']
plt.pie(data, labels=lb, autopct="%.0f%%", colors=['red','yellow','blue','lightgreen','green'])
plt.show()

# %%
import matplotlib.pyplot as plt #3.2
data = [40,25,20,10,15]
lb = ['Netflix','Viu','Disney Hotstar','We TV','iQIYI']
explode = [0,0.1,0,0.2,0]
plt.pie(data, labels=lb, explode=explode, startangle=90, colors=['red','yellow','blue','lightgreen','green'], shadow=True,autopct="%.1f%%")
plt.show()

# %%
import matplotlib.pyplot as plt #3.2
data = [35,20,25,4.5,15.5]
lb = ['Kerry','Flash','J&T','DHL','Thailand Post']
explode = [0,0,0,0,0.2]
plt.pie(data, labels=lb, explode=explode, startangle=90, colors=['orange','yellow','red','gold','royalblue'], shadow=True,autopct="%.1f%%")
plt.show()

# %%
import matplotlib.pyplot as plt #3.3
data = [40,25,20,10,15]
lb = ['Netflix','Viu','Disney Hotstar','We TV','iQIYI']
explode = [0,0.1,0,0.2,0]
plt.pie(data, labels=lb, explode=explode, startangle=90, colors=['red','yellow','blue','lightgreen','green'], shadow=True,autopct="%.1f%%", counterclock=False)
plt.show()

# %%
import matplotlib.pyplot as plt #3.3
data = [35,20,25,4.5,15.5]
lb = ['Kerry','Flash','J&T','DHL','Thailand Post']
explode = [0,0,0,0,0.2]
plt.pie(data, labels=lb, explode=explode, startangle=90, colors=['orange','yellow','red','gold','royalblue'], shadow=True,autopct="%.1f%%", counterclock=False)
plt.show()

# %%
import random
a = random.random()
print('a=',a)
# Out:
# a= 0.19289960485020297

# %%
import random
b = random.uniform(1.5,1.5)
print('b=',b)
# Out:
# b= 1.5

# %%
import random
c = random.randint(1,10)
print('c =',c)
# Out:
# c = 10

# %%
import random
d = random.choice(['ant','bird','cat','dog'])
print('d =',d)
# Out:
# d = dog

# %%
e = random.randrange(10,101,10)
print('e =',e)
# Out:
# e = 50

# %%
a = random.randint(0,9)
b = random.randint(0,9)
print(f'รางวลเลขท้าย 2 ตัว: {a}{b}')
# Out:
# รางวลเลขท้าย 2 ตัว: 90

# %%
#Honkai Star Rail Standard character generator
char = random.choice(['Clara','Gepard','Bailu','Bronya','Himeko','Yanqing','Welt'])
print('Your Character:',char)
# Out:
# Your Character: Himeko
